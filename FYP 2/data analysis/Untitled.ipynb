# %%
import pandas as pd 
#from geopy.geocoders import GoogleV3

df1 = pandas.read_csv("./Total_scrape_data_of_Alumni.csv") 
#geolocator = GoogleV3()

#DATA.googleaddress, (DATA.latitude, DATA.longitude) = geolocator.geocode(DATA.address)
#API_Key = "AIzaSyCqefpU1dTn7drOC_6u4s0VRpahfaYkEFw"
df=df1['job_location'] 
df. unique()
# Out:
# array(['Pakistan', 'Lahore, Pakistan',
#        'Los Angeles, California, United States',
#        'Lahore, Punjab, Pakistan', 'Islamabad, Pakistan',
#        'KarÄ\x81chi, Sindh, Pakistan', 'Islamabad',
#        'Islamabad, IslÄ\x81mÄ\x81bÄ\x81d, Pakistan', nan,
#        'Lahore District, Punjab, Pakistan', 'Faisalabad, Pakistan',
#        'Karachi', 'karachi,Pakistan', 'IslÄ\x81mÄ\x81bÄ\x81d, Pakistan',
#        'Karachi Division, Pakistan', 'Indonesia', 'Lahore',
#        'Karachi, Pakistan', 'Sindh, Pakistan',
#        'Pakpattan District, Punjab, Pakistan',
#        'Dubai, United Arab Emirates', 'Rawalpindi, Punjab, Pakistan',
#        'karachi', 'United States', 'Northern Punjab Rawalpindi, Pakistan',
#        'Punjab, Pakistan', 'San Francisco Bay Area',
#        'Faisalabad, Punjab, Pakistan', 'Rawalpindi', 'Swabi, Pakistan',
#        'New Jersey, United States',
#        'Santa Clara, California, United States',
# ...

# %%
#!pip install GoogleMaps
import googlemaps
from googlemaps import Client
gmaps_key= googlemaps.Client(key= "AIzaSyCqefpU1dTn7drOC_6u4s0VRpahfaYkEFw")

len(df)
# Out:
# 3052

# %%
df['LAT'] =None
df['LON']= None

for i in range(0, len(df), 1):
    geocode_result = gmaps_key.geocode(df.iat[i,0])
    
    try:
        lat= geocode_result[0]["geometry"]["location"]["lat"]
        lon= geocode_result[0]["geometry"]["location"]["lng"]
        df.iat[i,df.columns.get_loc('LAT')] = lat
        df.iat[i,df.columns.get_loc('LON')] = lon
        
    except:
        lat = None
        lon = None
# Out:
# ---------------------------------------------------------------------------
# ApiError                                  Traceback (most recent call last)
# <ipython-input-36-1f064b3e8232> in <module>
#       3
#       4 for i in range(0, len(df), 1):
# ----> 5     geocode_result = gmaps_key.geocode(df.iat[i,0])
#       6
#       7     try:
#
# c:\users\basha\appdata\local\programs\python\python39\lib\site-packages\googlemaps\client.py in wrapper(*args, **kwargs)
#     418     def wrapper(*args, **kwargs):
#     419         args[0]._extra_params = kwargs.pop("extra_params", None)
# --> 420         result = func(*args, **kwargs)
#     421         try:
#     422             del args[0]._extra_params
#
# c:\users\basha\appdata\local\programs\python\python39\lib\site-packages\googlemaps\geocoding.py in geocode(client, address, components, bounds, region, language)
#      66         params["language"] = language
#      67
# ...
