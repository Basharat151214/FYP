# %%
#!pip install mlxtend
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules
from apyori import apriori

# %%
store_data = pd.read_csv("./final_preprocess_data.csv", header=None)
store_data
# Out:
#                               0                         1   \
# 0                           Name           Current_Company
# 1                    abrar javed                    upwork
# 2                 mahrukh fatima  devbunch private limited
# 3                    neha nadeem                     daraz
# 4                    abdul rafeh         no joke marketing
# ...                          ...                       ...
# 2129           muhammad siddique       ccl pharmaceuticals
# 2130           agha hamza waheed                  carfirst
# 2131  mian muhammad faizan elahi                     tkxel
# 2132                hajra arshad                    online
# 2133               alishah saeed             consultechsol
#
#                                             2                    3   \
# 0                                  Current_Job           Total_year
# 1                                   freelancer   sep 2020 – present
# 2                          project coordinator   oct 2021 – present
# 3                                 data analyst   dec 2020 – present
# 4                  corporate marketing manager   oct 2021 – present
# ...                                        ...                  ...
# 2129  assistant manager contract manufacturing   sep 2020 – present
# 2130                     area manager purchase   mar 2019 – present
# 2131          sales development representative  aug 2020 – dec 2020
# 2132                                freelancer   aug 2018 – present
# 2133                         marketing manager   sep 2019 – present
#
#                                           4   \
# 0                               job_location
# 1                                   pakistan
# 2                           lahore, pakistan
# 3     los angeles, california, united states
# 4                              united states
# ...                                      ...
# 2129                        lahore, pakistan
# 2130                        lahore, pakistan
# 2131                lahore, punjab, pakistan
# 2132          islamabad, islamabad, pakistan
# 2133                lahore, punjab, pakistan
#
#                                            5                      6   \
# 0                                 Last_degree  Graduation_start_year
# 1          bachelor of electrical engineering                   2015
# 2         bachelor of business administration                   2014
# 3                bachelor of computer science                   2016
# 4                              masters degree                   2017
# ...                                       ...                    ...
# 2129      certified supply chain professional                   2020
# 2130                         bachelors degree                   2012
# 2131  master of business administration - mba                   2020
# 2132  master of business administration - mba                   2020
# 2133                         bachelors degree                   2015
#
#                        7                                     8   \
# 0     Graduation_end_year                       Last_University
# 1                    2020                            fast nuces
# 2                    2018                            fast nuces
# 3                    2020                            fast nuces
# 4                    2018                            fast nuces
# ...                   ...                                   ...
# 2129                 2020    piqc institute of quality pakistan
# 2130                 2017                            fast nuces
# 2131                 2022            lahore school of economics
# 2132                 2022  institute of business administration
# 2133                 2019                            fast nuces
#
#                                    9   \
# 0                          ProfileIDS
# 1          /in/abrar-javed-49854b14b/
# 2       /in/mahrukh-fatima-60b863106/
# 3                     /in/nehanadeem/
# 4                        /in/rafeh11/
# ...                               ...
# 2129  /in/muhammad-siddique-58480117/
# 2130  /in/agha-hamza-waheed-bb2384b1/
# 2131  /in/mian-muhammad-faizan-elahi/
# 2132                /in/hajra-arshad/
# 2133     /in/alishah-saeed-0b503a20b/
#
#                                                      10
# 0                                                skills
# 1     management||microsoft excel||customer service|...
# 2     microsoft office||customer service||microsoft ...
# 3     business intelligence (bi)||data analysis||dat...
# 4     microsoft office||microsoft excel||powerpoint|...
# ...                                                 ...
# 2129  market research||marketing management||team ma...
# 2130  microsoft office||team management||auditing||f...
# 2131  business analytics||digital marketing||search ...
# 2132  adobe photoshop||microsoft excel||microsoft wo...
# 2133  sales & marketing||media strategy||solutions m...
#
# [2134 rows x 11 columns]

# %%
records =[]
for i in range(0,2134):
    records.append([str(store_data.values[i,j]) for j in range(0, 5)])

# %%
#association_rules = apriori(records, min_support=0.0045, min_confidence=0.2, min_lift=3, min_length=2)
association_rules = apriori(records, min_support=0.0045, min_confidence=0.2, min_lift=3, min_length=2)
association_results = list(association_rules)
#association_results

# %%
print(len(association_results))
# Out:
# 15

# %%
print(association_results[0])
# Out:
# RelationRecord(items=frozenset({'kara\x81chi, sindh, pakistan', 'afiniti'}), support=0.008434864104967198, ordered_statistics=[OrderedStatistic(items_base=frozenset({'afiniti'}), items_add=frozenset({'kara\x81chi, sindh, pakistan'}), confidence=0.3673469387755102, lift=3.919591836734694)])

# %%
for item in association_results:                                          # to display the rule, the support, the confidence, and lift for each rule in a more clear way:

    # first index of the inner list
    # Contains base item and add item
    pair = item[0] 
    items = [x for x in pair]
    print("Rule: " + items[0] + " -> " + items[1])

    #second index of the inner list
    print("Support: " + str(item[1]))

    #third index of the list located at 0th
    #of the third index of the inner list

    print("Confidence: " + str(item[2][0][2]))
    print("Lift: " + str(item[2][0][3]))
    print("=====================================")
# Out:
# Rule: karachi, sindh, pakistan -> afiniti
# Support: 0.008434864104967198
# Confidence: 0.3673469387755102
# Lift: 3.919591836734694
# =====================================
# Rule: freelancer -> pakistan
# Support: 0.006091846298031865
# Confidence: 0.34210526315789475
# Lift: 3.333573660177842
# =====================================
# Rule: upwork -> freelancer
# Support: 0.006560449859418931
# Confidence: 0.36842105263157887
# Lift: 15.415892672858613
# =====================================
# Rule: jul 2021 to present -> karachi, sindh, pakistan
# Support: 0.014058106841611996
# Confidence: 0.2857142857142857
# Lift: 3.0485714285714285
# =====================================
# Rule: jul 2021 to present -> national university of computer and emerging sciences
# Support: 0.016869728209934397
# Confidence: 0.34285714285714286
# Lift: 4.434285714285714
# =====================================
# Rule: jun 2021 – present -> karachi, sindh, pakistan
# Support: 0.004686035613870665
# Confidence: 0.303030303030303
# Lift: 6.278317152103559
# =====================================
# Rule: karachi, sindh, pakistan -> oct 2021 to present
# Support: 0.005154639175257732
# Confidence: 0.28205128205128205
# Lift: 3.0094871794871794
# =====================================
# Rule: karachi, sindh, pakistan -> sep 2020 to present
# Support: 0.006560449859418931
# Confidence: 0.4242424242424242
# Lift: 4.526666666666666
# =====================================
# Rule: arbisoft -> software engineer
# Support: 0.004686035613870665
# Confidence: 0.47619047619047616
# Lift: 4.885531135531135
# =====================================
# Rule: jul 2021 to present -> karachi, sindh, pakistan
# Support: 0.009840674789128397
# Confidence: 0.3
# Lift: 3.2009999999999996
# =====================================
# Rule: jul 2021 to present -> national university of computer and emerging sciences
# Support: 0.015463917525773196
# Confidence: 0.3142857142857143
# Lift: 9.187475538160468
# =====================================
# Rule: jul 2021 to present -> software engineer
# Support: 0.01640112464854733
# Confidence: 0.3333333333333333
# Lift: 3.4198717948717943
# =====================================
# Rule: jul 2021 to present -> national university of computer and emerging sciences
# Support: 0.014526710402999063
# Confidence: 0.29523809523809524
# Lift: 5.122260936895083
# =====================================
# Rule: national university of computer and emerging sciences -> software engineer
# Support: 0.02717900656044986
# Confidence: 0.3515151515151515
# Lift: 3.606410256410256
# =====================================
# Rule: jul 2021 to present -> national university of computer and emerging sciences
# Support: 0.013120899718837863
# Confidence: 0.26666666666666666
# Lift: 9.811494252873564
# =====================================
